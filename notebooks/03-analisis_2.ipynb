# %%
import pandas as pd
from src.functions import archivo_limpio

# %%
df = archivo_limpio('../data/raw/QS WUR 2011-2022.xlsx')

# %%
df.sample(4)
# Out:
#        Year   Rank    O_Rank                       Institution   \
# 126  2015.0  127.0     127.0               Newcastle University
# 820  2021.0  900.5  801-1000  Bina Nusantara University (BINUS)
# 240  2016.0  241.0     241.0           Université De Strasbourg
# 156  2020.0  156.0     156.0                   Emory University
#
#     Academic Reputation AR Rank Employer Reputation ER Rank Faculty Student  \
# 126                53.0   223.0                74.9   131.0            68.4
# 820                   -       -                   -       -               -
# 240                72.3   135.0                27.0   401.0            20.6
# 156                26.9   312.0                11.8   501.0            99.7
#
#     FS Rank Citations per Faculty CF Rank International Faculty IF Rank  \
# 126   181.0                  67.0   164.0                  77.3   180.0
# 820       -                     -       -                     -       -
# ...

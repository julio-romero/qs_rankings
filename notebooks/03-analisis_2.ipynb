# %%
import pandas as pd
from src.functions import archivo_limpio

# %%
df = archivo_limpio('../data/raw/QS WUR 2011-2022.xlsx')

# %%
df.sample(4)
# Out:
#        Year   Rank   O_Rank                       Institution   \
# 340  2021.0  341.0    341                   Yeshiva University
# 163  2013.0  164.0    164.0    Case Western Reserve University
# 447  2020.0  448.0    448.0           Florida State University
# 330  2021.0  331.0     331=  National Taiwan Normal University
#
#     Academic Reputation AR Rank Employer Reputation ER Rank Faculty Student  \
# 340                 2.8    501+                 3.8    501+            97.0
# 163                27.4   301.0                 7.1   301.0            95.9
# 447                26.9   313.0                43.3   215.0            12.0
# 330                31.0   272.0                11.0    501+            68.5
#
#     FS Rank Citations per Faculty CF Rank  \
# 340    54.0                  49.8   219.0
# 163    51.0                  91.0    44.0
# 447   601.0                  35.4   382.0
# 330   203.0                  10.8    601+
#
# ...

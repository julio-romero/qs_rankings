# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Year'] = pd.to_datetime(df['Year'])

# %%
df.sample(5)
# Out:
#       Unnamed: 0  Year   Rank O_Rank                   Institution   \
# 925          165  2013  166.0    166  Queen'S University Of Belfast
# 2767         292  2017  291.0    291   Novosibirsk State University
# 3753         262  2019  481.0    481                UCSI University
# 2425         357  2016  358.0    358             University Of Oulu
# 1423         263  2014  264.0    264    Technische Universität Wien
#
#      Academic Reputation AR Rank Employer Reputation ER Rank Faculty Student  \
# 925                 45.4     240                  73      93            53.5
# 2767                28.9     373                34.2     360            86.6
# 3753                 6.5     501                  31     312            58.6
# 2425                30.2     401                21.1     401            61.4
# 1423                45.2     255                67.7     154              20
#
#      FS Rank Citations per Faculty CF Rank International Faculty IF Rank  \
# ...

# %% [markdown]
# ## Visualizacion

# %% [markdown]
# # Archivo limpio
#
# Podemos ver el excel limpio

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from src.functions_qs import archivo_limpio

# %%
df = archivo_limpio('../data/raw/QS WUR 2011-2022.xlsx')

# %%
df.sample(8)
# Out:
#       Year   Rank  O_Rank                            Institution   \
# 64  2020.0   64.0    64.0                 University of Amsterdam
# 62  2021.0   63.0    63    Ludwig-Maximilians-Universität München
# 31  2019.0   18.0    18.0                 University of Edinburgh
# 92  2014.0   92.0    92.0                 Université De Montréal
# 96  2021.0   97.0    97                           Lund University
# 57  2011.0   58.0    58.0          Technische Universität München
# 92  2019.0  163.0   163.0                  University of Waterloo
# 53  2015.0   54.0    54.0          Technische Universität München
#
#     Academic Reputation  AR Rank  Employer Reputation  ER Rank  \
# 64                 81.1     61.0                 56.0    143.0
# 62                 92.9     36.0                 80.7     75.0
# 31                 97.3     24.0                 94.0     34.0
# 92                 79.0    105.0                 59.6    211.0
# ...

# %% [markdown]
# ## Guardado
#
# Ahora que tenemos nuestro dataset limpio podemos guardarlom como csv, para poder trabajar con el

# %%
df = df.replace('601+',int(601))

# %%
df.to_excel('../data/processed/qs_wur.xlsx')

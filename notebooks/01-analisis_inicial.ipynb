# %% [markdown]
# # Analisis inicial
#
# Aqui se podria empezar la limpieza de Datos, e idear el analisis

# %%
import pandas as pd
from src.functions import lectura

# %%
excel_path = '../data/raw/QS WUR 2011-2022.xlsx'
df = lectura(excel_path)

# %%
df.sample(5)
# Out:
#        Year   Rank   O_Rank                               Institution   \
# 285  2017.0  283.0    283.0           King Abdul Aziz University (KAU)
# 284  2015.0  285.0    285.0  Queensland University Of Technology (QUT)
# 10   2014.0   10.0     10.0                       Princeton University
# 285  2021.0  286.0    286                University College Cork (UCC)
# 714  2021.0  725.5  701-750               Kaohsiung Medical University
#
#     Academic Reputation AR Rank Employer Reputation ER Rank Faculty Student  \
# 285                27.3   398.0                24.8   401.0            66.5
# 284                46.1   267.0                76.7   123.0            22.2
# 10                100.0    11.0                95.1    38.0            96.3
# 285                28.6   294.0                31.3   313.0            42.8
# 714                   -       -                   -       -            42.5
#
#     FS Rank Citations per Faculty CF Rank International Faculty IF Rank  \
# 285   175.0                  11.4   401.0                  99.0    63.0
# 284   401.0                  25.1   401.0                  97.6    56.0
# 10     50.0                  98.8    23.0                  76.3   169.0
# 285   364.0                  23.4   512.0                  91.9   154.0
# 714   370.0                  23.8   506.0                     -       -
#
#     International Students IS Rank Overall Score
# 285                   68.1   194.0          37.6
# 284                   52.1   264.0          43.2
# 10                    68.8   179.0          96.1
# 285                   46.4   314.0          34.9
# 714                      -       -   15.8 - 17.3

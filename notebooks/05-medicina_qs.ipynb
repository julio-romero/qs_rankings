# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# %%
path = '../data/raw/QS by Subjects 2014-2021.xlsx'

# %%
df_business=pd.read_excel(path,sheet_name='Business & Management Studies')
df_computer=pd.read_excel(path,sheet_name='Computer Science & Information ')
df_Eco=pd.read_excel(path,sheet_name='Economics & Econometrics')
df_Med=pd.read_excel(path,sheet_name='Medicine')
df_Eng=pd.read_excel(path,sheet_name='Engineering & Technology (Facul')

# %%
uni = 'Universidad de Los Andes Colombia'

# %%
#Se hace data frame con datos del Tec de Monterrey
datos_tecBusiness=df_business.loc[:,'Institution']==uni
df_tecBusiness=df_business.loc[datos_tecBusiness]

datos_tecComputer=df_computer.loc[:,'Institution']==uni
df_tecComputer=df_computer.loc[datos_tecComputer]

datos_tecEco=df_Eco.loc[:,'Institution']==uni
df_tecEco=df_Eco.loc[datos_tecEco]

datos_tecMed=df_Med.loc[:,'Institution']==uni
df_tecMed=df_Med.loc[datos_tecMed]

datos_tecEng=df_Eng.loc[:,'Institution']==uni
df_tecEng=df_Eng.loc[datos_tecEng]

df_tec=pd.concat([df_tecBusiness,df_tecComputer,df_tecEco,df_tecMed,df_tecEng])

datos_tecMed=df_Med.loc[:,'Institution']==uni
df_tecMed=df_Med.loc[datos_tecMed]

df_datosMedicina=pd.concat([datos_tecMed])

# %%
df_tecBusiness['Score']=df_tecBusiness['Score'].fillna(df_tecBusiness['Score'].median())
df_tecBusiness['Year']=df_tecBusiness['Year'].astype('string')
df_tecBusiness['H Score']=df_tecBusiness['H Score'].astype('float')
df_tecBusiness['Score']=df_tecBusiness['Score'].astype('float')
df_tecBusiness['Citations Score']=df_tecBusiness['Citations Score'].astype('float')


df_tecComputer['Score']=df_tecComputer['Score'].fillna(df_tecComputer['Score'].median())
df_tecComputer['Year']=df_tecComputer['Year'].astype('string')
#df_tecComputer['H Score']=pd.to_numeric(df_tecComputer['H Score'])
df_tecComputer['Score']=df_tecComputer['Score'].astype('float')
df_tecBusiness['H Score']=df_tecBusiness['H Score'].astype('float')
df_tecComputer['Citations Score']=df_tecComputer['Citations Score'].astype('float')
#df_tecComputer['Citations Score']=pd.to_numeric(df_tecComputer['Citations Score'])
#df_tecComputer['Academic Score']=pd.to_numeric(df_tecComputer['Academic Score'])

df_tecEco['Score']=df_tecEco['Score'].fillna(df_tecEco['Score'].median())
df_tecEco['Year']=df_tecEco['Year'].astype('string')
df_tecEco['H Score']=df_tecEco['H Score'].astype('float')
df_tecEco['Score']=df_tecEco['Score'].astype('float')
df_tecEco['Citations Score']=df_tecEco['Citations Score'].astype('float')

df_tecMed['Score']=df_tecMed['Score'].fillna(df_tecMed['Score'].median())
df_tecMed['Year']=df_tecMed['Year'].astype('string')
df_tecMed['H Score']=df_tecMed['H Score'].astype('float')
df_tecMed['Score']=df_tecMed['Score'].astype('float')
df_tecMed['Citations Score']=df_tecMed['Citations Score'].astype('float')

df_tecEng['Score']=df_tecEng['Score'].fillna(df_tecEng['Score'].median())
df_tecEng['Year']=df_tecEng['Year'].astype('string')
df_tecEng['H Score']=df_tecEng['H Score'].astype('float')
df_tecEng['Score']=df_tecEng['Score'].astype('float')
df_tecEng['Citations Score']=df_tecEng['Citations Score'].astype('float')
df_tecEng= df_tecEng.drop(['QS Region'],axis=1)


df_tec= df_tec.drop(['QS Region'],axis=1)
df_tecEng.head()
# Out:
# /var/folders/d_/jdkfxb9j7s5d540rn875nn2h0000gn/T/ipykernel_6342/2891218755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tecBusiness['Score']=df_tecBusiness['Score'].fillna(df_tecBusiness['Score'].median())
# /var/folders/d_/jdkfxb9j7s5d540rn875nn2h0000gn/T/ipykernel_6342/2891218755.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tecBusiness['Year']=df_tecBusiness['Year'].astype('string')
# ...

# %%
df_tec['H Score']=pd.to_numeric(df_tec['H Score'])
df_tec['Academic Score']=pd.to_numeric(df_tec['Academic Score'])
df_tec['Employer Score']=pd.to_numeric(df_tec['Employer Score'])
df_tec['Citations Score']=pd.to_numeric(df_tec['Citations Score'])

# %%
df_tec.to_excel('DatosTec.xlsx')
df_tecComputer.to_excel('DatosTec_Computer.xlsx')

# %%
df_tecMed.plot(x='Year',y=['Academic Score','Employer Score','Citations Score','H Score'],figsize=(10,7),kind='line')
name = "Medicina " + uni 
plt.title(name)
# Out:
# Text(0.5, 1.0, 'Medicina Universidad de Los Andes Colombia')

# %%
df_tecMed.plot(x='Year',y=['Score'],figsize=(10,7),kind='bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x="Year",y="Citations Score",hue='Subject',style='Subject',data=df_tec,marker='P',linestyle='-')
plt.title("TEC Citations Score")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x="Year",y="H Score",data=df_tecEng,marker='P',linestyle='-')
plt.title("Gráfica H score Engineering & Technology")
plt.show()

# %% [markdown]
# ## WUR

# %%
df_2011=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2011')
df_2012=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2012')
df_2013=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2013')
df_2015=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2014')
df_2016=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2015')
df_2017=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2016')
df_2018=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2017')
df_2019=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2019')
df_2020=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2020')
df_2021=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2021')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/manuelromero/Desktop/analisis_de_ciencia_de_datos/reto_qs_ranking/notebooks/05-medicina_qs.ipynb Cell 16' in <module>
# ----> <a href='vscode-notebook-cell:/Users/manuelromero/Desktop/analisis_de_ciencia_de_datos/reto_qs_ranking/notebooks/05-medicina_qs.ipynb#ch0000015?line=0'>1</a> df_2011=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2011')
#       <a href='vscode-notebook-cell:/Users/manuelromero/Desktop/analisis_de_ciencia_de_datos/reto_qs_ranking/notebooks/05-medicina_qs.ipynb#ch0000015?line=1'>2</a> df_2012=pd.read_excel('/content/QS WUR 2011-2022.xlsx',sheet_name='2012')
# ...

# %%
datos_tecBusiness=df_business.loc[:,'Institution']=='Tecnológico de Monterrey (ITESM)'
df_tecBusiness=df_business.loc[datos_tecBusiness]
